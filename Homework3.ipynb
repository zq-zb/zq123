# %% [markdown]
# 1.编写 Python程序,判断输入a是否为质数

# %%
#a=input()
a=5
flag=0
for i in range(2,(int)(a/2)):
    if a%i==0 and flag==0:
        print("No")
        flag=1
if flag==0:
    print("YEs")
# Out:
# YEs

# %% [markdown]
# 2.用Python实现插入排序该算法，不允许直接调用插入排序函数，需要手动实现其逻辑过程。

# %%
l=[]
#n=input()
n=5
for i in range(n):
    x=5;#x=input()
    l.append(x)
    for j in range(i):
        if l[i-j]<l[i-j-1]:
            tmp=l[i-j]
            l[i-j]=l[i-j-1]
            l[i-j-1]=tmp
        else:
            break
print(l);
# Out:
# [5, 5, 5, 5, 5]

# %% [markdown]
# 3.用Python实现选择排序该算法，不允许直接调用插入排序函数，需要手动实现其逻辑过程。

# %%
l=[]
n=5
for i in range(n): 
    x=input()
    l.append((int)(x))
for i in range(n):
    minn=10001
    minx=0
    for j in range(i,n):
        if minn>l[j]:
            minn=l[j]
            minx=j
    tmp=l[minx]
    l[minx]=l[i]
    l[i]=tmp
print(l)

# %% [markdown]
# 4.用Python实现快速排序该算法，不允许直接调用插入排序函数，需要手动实现其逻辑过程。

# %%
def quicksort(arr):
    if len(arr)<2:
        return arr
    else:
        x=arr[0]
        less=[i for i in arr[1:] if i<=x]
        mo=[i for i in arr[1:] if i>x]
        return quicksort(less)+[x]+quicksort(mo)
l=[9,5,4,3,2,1,8]
ar=quicksort(l)
print(ar)
# Out:
# [1, 2, 3, 4, 5, 8, 9]

# %% [markdown]
# 5.使用 Python 随机生成三组长度递增的随机数列，长度分别为100、1000、10000，对生成的随机数组使用不同的排序算法，例如选择排序和归并排序，至少三种排序方法。对这些数列的数据排序，并分析不同排序算法在不同长度数列下的运行效果，例如运行时间等指标。

# %%
import random
import time
def search(l):
    start_time=time.perf_counter();
    n=len(l)
    for i in range(n):
        minn=10001
        minx=0
        tmp=0
        for j in range(i,n):
          if minn>l[j]:
            minn=l[j]
            minx=j
        tmp=l[minx]
        l[minx]=l[i]
        l[i]=tmp
    end_time = time.perf_counter()  # 结束计时
    elapsed_time = end_time - start_time  # 计算运行时间
    print(f"运行时间: {elapsed_time:.6f} 秒")
    return l

def insert(l):
    start_time=time.perf_counter();
    n=len(l)
    for i in range(n):
      for j in range(i):
        if l[i-j]<l[i-j-1]:
            tmp=l[i-j]
            l[i-j]=l[i-j-1]
            l[i-j-1]=tmp
        else:
            break
    end_time = time.perf_counter()  # 结束计时
    elapsed_time = end_time - start_time  # 计算运行时间
    print(f"运行时间: {elapsed_time:.6f} 秒")
    return l

def quicksort(arr):
    if len(arr)<2:
        return arr
    else:
        x=arr[0]
        less=[i for i in arr[1:] if i<=x]
        mo=[i for i in arr[1:] if i>x]
        return quicksort(less)+[x]+quicksort(mo)

random1=[random.randint(1,1000) for _ in range(100)]
random2=[random.randint(1,10000) for _ in range(1000)]
random3=[random.randint(1,10000) for _ in range(10000)]

rand1=search(random1)
rand2=insert(random2)
start_time=time.perf_counter();
rand3=quicksort(random3)
end_time = time.perf_counter()  # 结束计时
elapsed_time = end_time - start_time  # 计算运行时间
print(f"运行时间: {elapsed_time:.6f} 秒")
print(rand1)
print(rand2)
print(rand3)
# Out:
# 运行时间: 0.000203 秒
# 运行时间: 0.050051 秒
# 运行时间: 0.021059 秒
# [5, 7, 17, 28, 38, 43, 46, 47, 48, 71, 73, 87, 90, 94, 97, 98, 103, 108, 109, 110, 114, 134, 165, 166, 166, 180, 198, 222, 231, 236, 242, 252, 289, 296, 306, 308, 310, 312, 327, 328, 329, 333, 334, 349, 364, 365, 366, 367, 385, 387, 394, 413, 417, 423, 433, 438, 444, 464, 466, 467, 479, 487, 493, 495, 520, 529, 539, 539, 552, 583, 586, 605, 649, 660, 672, 680, 711, 716, 725, 735, 738, 752, 773, 815, 818, 842, 846, 852, 866, 872, 886, 893, 908, 934, 947, 957, 960, 975, 978, 987]
# ...

# %% [markdown]
# 6.使用python代码获取当前系统时间

# %%
from datetime import datetime

now=datetime.now()
print("日期和时间",now)
now=now.strftime("%Y-%m-%d %H:%M:%S")
print("日期和时间",now);
# Out:
# 日期和时间 2024-10-15 15:50:04.322950
# 日期和时间 2024-10-15 15:50:04

# %% [markdown]
# 7.homework/data文件夹下的stuGrade.csv文件中包含5位同学的学号、语文成绩、数学成绩和英语成绩，请先用记事本打开该文件，查看文件内容，然后编写Python程序，读取该文件，并计算出各科的平均成绩（保留2位小数）。

# %%
import csv

with open('stuGrade.csv',mode='r',newline='',encoding='utf-8') as file:
    csv_reader=csv.reader(file)
    next(csv_reader)
    sum1=0
    sum2=0
    sum3=0
    for row in csv_reader:
        sum1=sum1+(int)(row[1])
        sum2=sum2+(int)(row[2])
        sum3=sum3+(int)(row[3])
    ans1="{:.2f}".format(sum1*1.0/5)
    ans2="{:.2f}".format(sum2*1.0/5)
    ans3="{:.2f}".format(sum3*1.0/5)
    print(ans1,ans2,ans3)
# Out:
# 82.60 81.00 81.80

# %% [markdown]
# 8.请在第7题的代码继续编写Python程序，将以下内容写入my.txt文件中，一并上传到github中。

# %%
import csv

with open('stuGrade.csv',mode='r',newline='',encoding='utf-8') as file:
    csv_reader=csv.reader(file)
    next(csv_reader)
    sum1=0
    sum2=0
    sum3=0
    for row in csv_reader:
        sum1=sum1+(int)(row[1])
        sum2=sum2+(int)(row[2])
        sum3=sum3+(int)(row[3])
    ans1="{:.2f}".format(sum1*1.0/5)
    ans2="{:.2f}".format(sum2*1.0/5)
    ans3="{:.2f}".format(sum3*1.0/5)

lines=[ans1,ans2,ans3]
with open('my.txt','w',encoding='utf-8') as file:
    for i in lines:
       file.write(i+' ')
